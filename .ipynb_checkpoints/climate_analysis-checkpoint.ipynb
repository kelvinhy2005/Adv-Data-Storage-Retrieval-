# %%
import matplotlib
matplotlib.use('nbagg')
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import pandas as pd
import numpy as np
import os
import sqlalchemy
from sqlalchemy import create_engine, MetaData
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Text, Float, Date,func, inspect

csv_file1 = 'clean_measurments.csv'
csv_file2 = 'clean_stations.csv'
measurments_df = pd.read_csv(csv_file1)
stations_df = pd.read_csv(csv_file2)
engine = create_engine("sqlite:///hawaii.sqlite")
conn = engine.connect()

# %%
#measurments_df.to_sql(name='measurment', con=conn, flavor='sqlite',if_exists='append',index=False)

# %%
#stations_df.to_sql(name='station',con=conn,flavor='sqlite',if_exists='append',index=False)

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['measurements_clean',
#  'measurment',
#  'measurments',
#  'observations',
#  'station',
#  'stations']

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Measurements = Base.classes.observations
Stations = Base.classes.stations

# %%
session = Session(engine)

# %% [markdown]
# # Precipitation Analysis

# %%
results = session.query(Measurements.date,Measurements.prcp).order_by(Measurements.date.asc()).all()

# %%
df = pd.DataFrame(results, columns=['observ_time','observ_prcp'])
df['observ_time']=pd.DataFrame(df['observ_time'])

# %%
import seaborn as sns

# %%
df.plot(x='observ_time',y='observ_prcp',kind = 'bar',title = 'Precipitation Over Time')
plt.show()
# Out:
# <div id='ebf3e717-6563-49f2-8414-0a412e379151'></div>

# %% [markdown]
# # Station Analysis

# %%
observCt_results = session.query(func.count(Measurements.date))
observCt_results

# %%
q2_results = session.query(Stations.name,func.count(Measurements.date)).filter(Stations.station == Measurements.station)\
            .group_by(Measurements.station).all()

# %%
df2 = pd.DataFrame(q2_results,columns=['station_name','observ_ct']).sort_values(by = 'observ_ct')
df2
# Out:
#                              station_name  observ_ct
# 5              UPPER WAHIAWA 874.3, HI US        342
# 4                       PEARL CITY, HI US        683
# 0       HONOLULU OBSERVATORY 702.2, HI US       1932
# 2  KUALOA RANCH HEADQUARTERS 886.9, HI US       1937
# 3            MANOA LYON ARBO 785.2, HI US       2484
# 8      WAIMANALO EXPERIMENTAL FARM, HI US       2572
# 7                    WAIKIKI 717.2, HI US       2685
# 1                    KANEOHE 838.1, HI US       2696
# 6                     WAIHEE 837.5, HI US       2772

# %%
df2.plot(x='station_name',y='observ_ct',kind = 'bar',title = 'Observation Frequency by Station')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
q3_results = session.query(Stations.name,Measurements.tobs).filter(Stations.station == Measurements.station,)\
            .filter(Stations.name == 'WAIHEE 837.5, HI US').all()
q3_results
# Out:
# [('WAIHEE 837.5, HI US', '54'),
#  ('WAIHEE 837.5, HI US', '56'),
#  ('WAIHEE 837.5, HI US', '56'),
#  ('WAIHEE 837.5, HI US', '56'),
#  ('WAIHEE 837.5, HI US', '56'),
#  ('WAIHEE 837.5, HI US', '57'),
#  ('WAIHEE 837.5, HI US', '57'),
#  ('WAIHEE 837.5, HI US', '57'),
#  ('WAIHEE 837.5, HI US', '57'),
#  ('WAIHEE 837.5, HI US', '57'),
#  ('WAIHEE 837.5, HI US', '57'),
#  ('WAIHEE 837.5, HI US', '58'),
#  ('WAIHEE 837.5, HI US', '58'),
#  ('WAIHEE 837.5, HI US', '58'),
#  ('WAIHEE 837.5, HI US', '58'),
#  ('WAIHEE 837.5, HI US', '58'),
#  ('WAIHEE 837.5, HI US', '58'),
#  ('WAIHEE 837.5, HI US', '59'),
#  ('WAIHEE 837.5, HI US', '59'),
#  ('WAIHEE 837.5, HI US', '59'),
#  ('WAIHEE 837.5, HI US', '59'),
#  ('WAIHEE 837.5, HI US', '59'),
#  ('WAIHEE 837.5, HI US', '60'),
#  ('WAIHEE 837.5, HI US', '60'),
#  ('WAIHEE 837.5, HI US', '60'),
#  ('WAIHEE 837.5, HI US', '60'),
#  ('WAIHEE 837.5, HI US', '60'),
#  ('WAIHEE 837.5, HI US', '60'),
#  ('WAIHEE 837.5, HI US', '60'),
# ...

# %%
df3 = pd.DataFrame(q3_results,columns=['station_name','observed_tobs'])
df3['observed_tobs']=df3['observed_tobs'].astype(float)
df3.dtypes
# Out:
# station_name      object
# observed_tobs    float64
# dtype: object

# %%
df3['observed_tobs'].plot(kind = 'hist',bins = 12)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Temperature Analysis

# %%
q4_results = session.query(Measurements.tobs).filter(Stations.station == Measurements.station,)\
            .filter(Measurements.date >= '2017-01-01').filter(Measurements.date<='2018-01-01').all()

# %%
df4 = pd.DataFrame(q4_results,columns=['tobs'])
df4.columns
# Out:
# Index(['tobs'], dtype='object')

# %%
df4['tobs']=df4['tobs'].astype(int)
tobs_mean = df4['tobs'].mean()
tobs_max = df4['tobs'].max()
tobs_min = df4['tobs'].min()

# %%
x_axis =['']
plt.bar(x_axis,tobs_mean,width=0.35,yerr = (tobs_max - tobs_min))
plt.title("Trip Average Temperature")
plt.ylabel("Farenheit")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
